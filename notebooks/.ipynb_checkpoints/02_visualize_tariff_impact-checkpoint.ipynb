# %%
import pandas as pd

nifty = pd.read_csv('../data/nifty50_close_prices_2025.csv')
tariffs = pd.read_csv('../data/tariff_events_2025.csv')

# %%
print(nifty.head())
print(tariffs.head(3))
# Out:
#          Date  ADANIENT.NS  ADANIPORTS.NS  APOLLOHOSP.NS  ASIANPAINT.NS  \
# 0  2025-01-01  2554.850098    1218.699951    7359.241211    2304.649902
# 1  2025-01-02  2597.699951    1226.000000    7411.167480    2343.250000
# 2  2025-01-03  2564.600098    1199.550049    7288.041992    2335.949951
# 3  2025-01-06  2474.449951    1163.050049    7418.657227    2267.149902
# 4  2025-01-07  2520.550049    1174.000000    7426.246582    2292.600098
#
#    AXISBANK.NS  BAJAJ-AUTO.NS  BAJAJFINSV.NS  BAJFINANCE.NS  BHARTIARTL.NS  \
# 0  1071.800049    8740.549805    1576.400024    6935.299805    1595.699951
# 1  1086.599976    9079.500000    1700.650024    7389.200195    1609.699951
# 2  1084.900024    8965.700195    1701.099976    7407.250000    1598.849976
# 3  1063.400024    8823.849609    1684.599976    7349.350098    1588.449951
# 4  1067.500000    8810.299805    1682.750000    7353.950195    1590.849976
#
#    ...  SUNPHARMA.NS  TATACONSUM.NS  TATAMOTORS.NS  TATASTEEL.NS       TCS.NS  \
# 0  ...   1878.628052     920.299988     749.250000    136.740005  4047.922852
# 1  ...   1866.749756     929.650024     765.049988    138.179993  4110.229492
# 2  ...   1838.569580     939.450012     790.400024    138.360001  4035.569336
# 3  ...   1836.333008     946.900024     776.250000    132.179993  4030.746338
# 4  ...   1842.297119     955.000000     793.250000    133.380005  3965.093018
#
#       TECHM.NS     TITAN.NS  ULTRACEMCO.NS      UPL.NS    WIPRO.NS
# 0  1703.849976  3253.850098   11447.000000  500.500000  294.449036
# 1  1726.949951  3388.949951   11797.700195  509.450012  297.880859
# 2  1689.449951  3451.649902   11786.000000  529.549988  288.713043
# 3  1686.300049  3470.399902   11503.599609  521.299988  288.565948
# 4  1671.150024  3505.100098   11618.549805  544.450012  288.320801
#
# [5 rows x 51 columns]
#          Date                                              Event
# 0  2025-02-15  Trump imposes 15% tariffs on Indian manufactur...
# 1  2025-03-10  India retaliates with tariffs on U.S. electron...
# 2  2025-04-01  Trump raises tariffs to 25% on all Indian impo...

# %%
print(nifty.dtypes)
print(tariffs.dtypes)
# Out:
# Date              object
# ADANIENT.NS      float64
# ADANIPORTS.NS    float64
# APOLLOHOSP.NS    float64
# ASIANPAINT.NS    float64
# AXISBANK.NS      float64
# BAJAJ-AUTO.NS    float64
# BAJAJFINSV.NS    float64
# BAJFINANCE.NS    float64
# BHARTIARTL.NS    float64
# BPCL.NS          float64
# BRITANNIA.NS     float64
# CIPLA.NS         float64
# COALINDIA.NS     float64
# DIVISLAB.NS      float64
# DRREDDY.NS       float64
# EICHERMOT.NS     float64
# GRASIM.NS        float64
# HCLTECH.NS       float64
# HDFCBANK.NS      float64
# HDFCLIFE.NS      float64
# HEROMOTOCO.NS    float64
# HINDALCO.NS      float64
# HINDUNILVR.NS    float64
# ICICIBANK.NS     float64
# ICICIPRULI.NS    float64
# INDUSINDBK.NS    float64
# INFY.NS          float64
# ITC.NS           float64
# JSWSTEEL.NS      float64
# KOTAKBANK.NS     float64
# LT.NS            float64
# M&M.NS           float64
# MARUTI.NS        float64
# NESTLEIND.NS     float64
# NTPC.NS          float64
# ONGC.NS          float64
# POWERGRID.NS     float64
# RELIANCE.NS      float64
# SBILIFE.NS       float64
# SBIN.NS          float64
# SUNPHARMA.NS     float64
# TATACONSUM.NS    float64
# TATAMOTORS.NS    float64
# TATASTEEL.NS     float64
# TCS.NS           float64
# TECHM.NS         float64
# TITAN.NS         float64
# ULTRACEMCO.NS    float64
# UPL.NS           float64
# WIPRO.NS         float64
# dtype: object
# Date     object
# Event    object
# dtype: object

# %%
nifty['Date'] = pd.to_datetime(nifty['Date'])
tariffs['Date'] = pd.to_datetime(tariffs['Date'])

# %%
print(nifty.isnull().sum())
print(tariffs.isnull().sum())
# Out:
# Date             0
# ADANIENT.NS      0
# ADANIPORTS.NS    0
# APOLLOHOSP.NS    0
# ASIANPAINT.NS    0
# AXISBANK.NS      0
# BAJAJ-AUTO.NS    0
# BAJAJFINSV.NS    0
# BAJFINANCE.NS    0
# BHARTIARTL.NS    0
# BPCL.NS          0
# BRITANNIA.NS     0
# CIPLA.NS         0
# COALINDIA.NS     0
# DIVISLAB.NS      0
# DRREDDY.NS       0
# EICHERMOT.NS     0
# GRASIM.NS        0
# HCLTECH.NS       0
# HDFCBANK.NS      0
# HDFCLIFE.NS      0
# HEROMOTOCO.NS    0
# HINDALCO.NS      0
# HINDUNILVR.NS    0
# ICICIBANK.NS     0
# ICICIPRULI.NS    0
# INDUSINDBK.NS    0
# INFY.NS          0
# ITC.NS           0
# JSWSTEEL.NS      0
# KOTAKBANK.NS     0
# LT.NS            0
# M&M.NS           0
# MARUTI.NS        0
# NESTLEIND.NS     0
# NTPC.NS          0
# ONGC.NS          0
# POWERGRID.NS     0
# RELIANCE.NS      0
# SBILIFE.NS       0
# SBIN.NS          0
# SUNPHARMA.NS     0
# TATACONSUM.NS    0
# TATAMOTORS.NS    0
# TATASTEEL.NS     0
# TCS.NS           0
# TECHM.NS         0
# TITAN.NS         0
# ULTRACEMCO.NS    0
# UPL.NS           0
# WIPRO.NS         0
# dtype: int64
# Date     0
# Event    0
# dtype: int64

# %%
print(nifty.describe())
print(tariffs.describe())
# Out:
#                                 Date  ADANIENT.NS  ADANIPORTS.NS  \
# count                             78    78.000000      78.000000
# mean   2025-02-24 17:13:50.769230848  2318.272452    1140.647431
# min              2025-01-01 00:00:00  2096.000000    1053.050049
# 25%              2025-01-28 06:00:00  2246.262573    1100.074982
# 50%              2025-02-22 12:00:00  2318.625000    1136.674988
# 75%              2025-03-24 18:00:00  2384.825012    1176.774963
# max              2025-04-25 00:00:00  2597.699951    1259.400024
# std                              NaN   111.530872      51.352270
#
#        APOLLOHOSP.NS  ASIANPAINT.NS  AXISBANK.NS  BAJAJ-AUTO.NS  \
# count      78.000000      78.000000    78.000000      78.000000
# mean     6668.164000    2293.833330  1046.267953    8263.090983
# min      6052.600098    2132.100098   948.099976    7306.799805
# 25%      6363.786743    2242.900024  1007.600021    7914.150146
# 50%      6707.012207    2275.775024  1034.125000    8399.175293
# 75%      6878.508667    2337.562561  1077.124969    8639.237549
# max      7426.246582    2467.899902  1223.000000    9155.599609
# std       354.258975      73.831233    62.246365     501.876061
#
#        BAJAJFINSV.NS  BAJFINANCE.NS  BHARTIARTL.NS  ...  SUNPHARMA.NS  \
# count      78.000000      78.000000      78.000000  ...     78.000000
# mean     1835.745512    8278.823036    1673.663458  ...   1725.845016
# min      1576.400024    6935.299805    1570.199951  ...   1566.500000
# 25%      1744.937469    7644.862549    1620.625000  ...   1689.537476
# 50%      1840.825012    8426.199707    1643.174988  ...   1732.224976
# 75%      1895.487457    8703.600342    1718.362549  ...   1766.885468
# max      2105.000000    9323.000000    1889.099976  ...   1878.628052
# std       114.008978     649.737632      76.767982  ...     67.652334
#
#        TATACONSUM.NS  TATAMOTORS.NS  TATASTEEL.NS       TCS.NS     TECHM.NS  \
# count      78.000000      78.000000     78.000000    78.000000    78.000000
# mean     1004.000639     690.137817    138.840640  3760.896318  1550.072433
# min       920.299988     579.750000    122.930000  3231.500000  1272.750000
# 25%       959.962479     654.275009    131.700005  3507.412476  1438.625031
# 50%       978.725006     683.125000    136.855003  3727.500000  1627.099976
# 75%      1027.362488     725.449997    144.955006  4060.843140  1670.887512
# max      1161.300049     794.950012    159.039993  4223.769531  1726.949951
# std        59.824750      55.014933      9.658187   308.318234   139.897664
#
#           TITAN.NS  ULTRACEMCO.NS      UPL.NS    WIPRO.NS
# count    78.000000      78.000000   78.000000   78.000000
# mean   3254.470512   11191.744879  610.564104  282.757944
# min    2986.949951   10128.450195  500.500000  234.149994
# 25%    3090.349915   10674.287354  554.287476  264.074997
# 50%    3254.650024   11289.574707  627.000000  286.384308
# 75%    3370.162476   11508.062256  646.337479  305.212502
# max    3597.699951   12237.000000  684.200012  319.049988
# std     160.128034     491.784905   47.397799   25.089102
#
# [8 rows x 51 columns]
#                       Date
# count                    3
# mean   2025-03-09 16:00:00
# min    2025-02-15 00:00:00
# 25%    2025-02-26 12:00:00
# 50%    2025-03-10 00:00:00
# 75%    2025-03-21 00:00:00
# max    2025-04-01 00:00:00

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load data
nifty = pd.read_csv('../data/nifty50_close_prices_2025.csv', parse_dates=['Date'])
tariffs = pd.read_csv('../data/tariff_events_2025.csv', parse_dates=['Date'])

# Calculate average close price (excluding 'Date' column)
nifty['Average_Close'] = nifty.drop(columns=['Date']).mean(axis=1)

# Plot Average Close Price
plt.figure(figsize=(14, 7))
plt.plot(nifty['Date'], nifty['Average_Close'], label='Average Close Price (NIFTY 50)', color='blue')


# Mark Tariff Events
for idx, row in tariffs.iterrows():
    event_date = row['Date']
    event_desc = row['Event']
    price_on_event = nifty.loc[nifty['Date'] == event_date, 'Average_Close']

    if not price_on_event.empty:
        y = price_on_event.values[0]
        plt.axvline(x=event_date, color='red', linestyle='--', linewidth=1)
        plt.text(
            x=event_date,
            y=y + 25,  # move label above the point
            s=event_desc,
            fontsize=9,
            color='darkred',
            ha='center',
            bbox=dict(boxstyle='round,pad=0.3', edgecolor='red', facecolor='white')
        )


# Final Formatting
plt.title('NIFTY 50 - Average Close Price with Tariff Events (2025)', fontsize=16)
plt.xlabel('Date')
plt.ylabel('Average Close Price (INR)')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load data
nifty = pd.read_csv('../data/nifty50_close_prices_2025.csv', parse_dates=['Date'])
tariffs = pd.read_csv('../data/tariff_events_2025.csv', parse_dates=['Date'])

# Calculate average close price (excluding 'Date' column)
nifty['Average_Close'] = nifty.drop(columns=['Date']).mean(axis=1)


# Compute percent change in average close price around each event
window = 5  # days before and after
impact_results = []

for idx, row in tariffs.iterrows():
    event_date = row['Date']
    event_desc = row['Event']

    # Get index of the event date in nifty
    if event_date not in nifty['Date'].values:
        continue  # skip if date doesn't exist in data

    event_idx = nifty.index[nifty['Date'] == event_date][0]

    # Get 5-day window before and after
    pre_window = nifty.iloc[max(event_idx - window, 0):event_idx]['Average_Close'].mean()
    post_window = nifty.iloc[event_idx + 1:event_idx + 1 + window]['Average_Close'].mean()

    # Calculate percent change
    pct_change = ((post_window - pre_window) / pre_window) * 100
    impact_results.append({
        'Date': event_date,
        'Event': event_desc,
        'Pre Avg': round(pre_window, 2),
        'Post Avg': round(post_window, 2),
        '% Change': round(pct_change, 2)
    })

# Convert to DataFrame for display
impact_df = pd.DataFrame(impact_results)
print(impact_df)
# Out:
#         Date                                              Event  Pre Avg  \
# 0 2025-03-10  India retaliates with tariffs on U.S. electron...  2354.41
# 1 2025-04-01  Trump raises tariffs to 25% on all Indian impo...  2470.12
#
#    Post Avg  % Change
# 0   2353.61     -0.03
# 1   2416.37     -2.18

# %%
import pandas as pd
import matplotlib.pyplot as plt

nifty['Average_Close'] = nifty.drop(columns=['Date']).mean(axis=1)

# Calculate 10-day rolling volatility (standard deviation)
nifty['Volatility'] = nifty['Average_Close'].rolling(window=10).std()

# Plot
plt.figure(figsize=(14, 7))
plt.plot(nifty['Date'], nifty['Volatility'], label='10-Day Rolling Volatility', color='purple')

# Mark tariff events
for idx, row in tariffs.iterrows():
    event_date = row['Date']
    event_desc = row['Event']
    
    plt.axvline(x=event_date, color='red', linestyle='--', linewidth=1)
    plt.annotate(
        event_desc,
        xy=(event_date, nifty['Volatility'].max()*0.8),
        xytext=(event_date, nifty['Volatility'].max()),
        arrowprops=dict(facecolor='red', arrowstyle='->'),
        fontsize=8,
        rotation=90,
        ha='center'
    )

# Formatting
plt.title('NIFTY 50 - Volatility Around Tariff Events (2025)', fontsize=16)
plt.xlabel('Date', fontsize=12)
plt.ylabel('Volatility (Std Dev of Average Close)', fontsize=12)
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
